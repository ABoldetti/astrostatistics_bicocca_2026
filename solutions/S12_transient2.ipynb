# %%
import numpy as np
import pylab as plt
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams['font.size'] = 12
import emcee
import scipy.stats
import corner
import dynesty
from dynesty import utils as dyfunc
from dynesty import plotting as dyplot
import warnings

# %%
import numpy as np
import pylab as plt
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams['font.size'] = 12
import emcee
import scipy.stats
import corner
import dynesty
from dynesty import utils as dyfunc
from dynesty import plotting as dyplot
import warnings

# %%
data= np.load('transient.npy')

# %%
data= np.load('transient.npy')

# %% [markdown]
# First, always start with a quick look at the data

# %%
t,y,yerr=data.T
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux");

# %%
t,y,yerr=data.T
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux");

# %% [markdown]
# These are the old burst model and the new gaussian profile model:

# %%
def burst(theta,t):
    A,b,t0,alpha=theta 
    return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))

def gprofile(theta,t):
    A,b,t0,sigmaW=theta     
    return b+A*np.exp(-(((t-t0)/sigmaW)**2 ) / 2)

t0min,t0max = 0,100
Amin,Amax=0,50
bmin,bmax=0,50
alphamin,alphamax=np.exp(-5),np.exp(5)
sigmaWmin,sigmaWmax=np.exp(-2),np.exp(2)

# %%
def burst(theta,t):
    A,b,t0,alpha=theta 
    return np.where(t<t0,b,b+A*np.exp(-alpha*(t-t0)))

def gprofile(theta,t):
    A,b,t0,sigmaW=theta     
    return b+A*np.exp(-(((t-t0)/sigmaW)**2 ) / 2)

t0min,t0max = 0,100
Amin,Amax=0,50
bmin,bmax=0,50
alphamin,alphamax=np.exp(-5),np.exp(5)
sigmaWmin,sigmaWmax=np.exp(-2),np.exp(2)

# %% [markdown]
# First, let's reproduce our previous results using dynesty

# %%
ndim = 4

def loglike(theta, data, model):
    x, y, sigma_y = data.T
    if model =='burst':
        y_fit = burst(theta, x)
    elif model == 'gprofile':
        y_fit = gprofile(theta, x)

    # Note I'm not tracking the normalization here! 
    # Ok because here I only care about the ratio between two evidences, not the evidence itself
    return -0.5 * np.sum((y-y_fit)**2 / sigma_y**2 ) 


def ptform(u,model):
    """Transforms the uniform random variables `u ~ Unif[0., 1.)`
    to the parameters of interest."""

    x = np.array(u)  # copy u

    x[0] = scipy.stats.uniform(loc=Amin,scale=Amax-Amin).ppf(u[0])
    x[1] = scipy.stats.uniform(loc=bmin,scale=bmax-bmin).ppf(u[1])
    x[2] = scipy.stats.uniform(loc=t0min,scale=t0max-t0min).ppf(u[2])
   
    if model =='burst':
        x[3] = scipy.stats.loguniform.ppf(u[3],alphamin,alphamax)
    elif model =='gprofile':
        x[3] = scipy.stats.loguniform.ppf(u[3],sigmaWmin,sigmaWmax)
        #x[3] = scipy.stats.uniform(loc=sigmaWmin,scale=sigmaWmax-sigmaWmin).ppf(u[3])

    return x

# %%
ndim = 4

def loglike(theta, data, model):
    x, y, sigma_y = data.T
    if model =='burst':
        y_fit = burst(theta, x)
    elif model == 'gprofile':
        y_fit = gprofile(theta, x)

    # Note I'm not tracking the normalization here! 
    # Ok because here I only care about the ratio between two evidences, not the evidence itself
    return -0.5 * np.sum((y-y_fit)**2 / sigma_y**2 ) 


def ptform(u,model):
    """Transforms the uniform random variables `u ~ Unif[0., 1.)`
    to the parameters of interest."""

    x = np.array(u)  # copy u

    x[0] = scipy.stats.uniform(loc=Amin,scale=Amax-Amin).ppf(u[0])
    x[1] = scipy.stats.uniform(loc=bmin,scale=bmax-bmin).ppf(u[1])
    x[2] = scipy.stats.uniform(loc=t0min,scale=t0max-t0min).ppf(u[2])
   
    if model =='burst':
        x[3] = scipy.stats.loguniform.ppf(u[3],alphamin,alphamax)
    elif model =='gprofile':
        x[3] = scipy.stats.loguniform.ppf(u[3],sigmaWmin,sigmaWmax)
        #x[3] = scipy.stats.uniform(loc=sigmaWmin,scale=sigmaWmax-sigmaWmin).ppf(u[3])

    return x

# %%
with warnings.catch_warnings():
    # Potentially dangerous, but hey I know what I'm doing. 
    # Those warnings come from regions where the likelihood is ~zero
    warnings.simplefilter("ignore", category=RuntimeWarning)

    # Define and run sampler
    sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'burst'],ptform_args=['burst'],nlive=300)
    sampler.run_nested()
    sresults = sampler.results
# Out:
# 4730it [02:52, 27.35it/s, +300 | bound: 227 | nc: 1 | ncall: 113206 | eff(%):  4.455 | loglstar:   -inf < -48.777 <    inf | logz: -63.265 +/-  0.213 | dlogz:  0.001 >  0.309]

# %%
with warnings.catch_warnings():
    # Potentially dangerous, but hey I know what I'm doing. 
    # Those warnings come from regions where the likelihood is ~zero
    warnings.simplefilter("ignore", category=RuntimeWarning)

    # Define and run sampler
    sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'burst'],ptform_args=['burst'],nlive=300)
    sampler.run_nested()
    sresults = sampler.results
# Out:
# 2171it [00:47,  9.23it/s, bound: 121 | nc: 206 | ncall: 59617 | eff(%):  3.642 | loglstar:   -inf < -86.789 <    inf | logz: -92.959 +/-  0.134 | dlogz: 34.995 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2203it [00:57, 11.10it/s, bound: 130 | nc: 45 | ncall: 71461 | eff(%):  3.083 | loglstar:   -inf < -86.533 <    inf | logz: -92.920 +/-  0.134 | dlogz: 34.849 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3138it [01:22, 152.05it/s, bound: 207 | nc: 11 | ncall: 103508 | eff(%):  3.032 | loglstar:   -inf < -60.802 <    inf | logz: -73.123 +/-  0.194 | dlogz: 13.881 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4613it [01:31, 50.14it/s, +300 | bound: 243 | nc: 1 | ncall: 114906 | eff(%):  4.287 | loglstar:   -inf < -48.760 <    inf | logz: -62.858 +/-  0.210 | dlogz:  0.001 >  0.309]

# %%
rfig, raxes = dyplot.runplot(sresults)

# %%
rfig, raxes = dyplot.runplot(sresults)

# %%
tfig, taxes = dyplot.traceplot(sresults)

# %%
tfig, taxes = dyplot.traceplot(sresults)

# %%
samples = sresults.samples  # samples
weights = np.exp(sresults.logwt - sresults.logz[-1])  # normalized weights

labels = ["A","b","t0","alpha"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
samples = sresults.samples  # samples
weights = np.exp(sresults.logwt - sresults.logz[-1])  # normalized weights

labels = ["A","b","t0","alpha"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
quantiles = [dyfunc.quantile(samps, [0.05, 0.5, 0.95], weights=weights)
             for samps in samples.T]
for q,l in zip(quantiles,labels):
    low,med,up=q
    print(l+"   "+str(med)+" +"+str(up-med)+" -"+str(med-low))
# Out:
# A   5.3223565270421 +3.2125026489014292 -1.7421462015812899
# b   10.294860066175536 +0.20496479690158687 -0.20426829425583115
# t0   49.00710276597706 +2.8197140175028466 -1.9640468622085194
# alpha   0.1213868556382462 +0.05287143822228804 -0.03703674632706584

# %%
quantiles = [dyfunc.quantile(samps, [0.05, 0.5, 0.95], weights=weights)
             for samps in samples.T]
for q,l in zip(quantiles,labels):
    low,med,up=q
    print(l+"   "+str(med)+" +"+str(up-med)+" -"+str(med-low))
# Out:
# A   5.422054427185757 +3.500400520652609 -1.8367937973817128
# b   10.302328249975062 +0.19959547328016924 -0.2110881461994687
# t0   49.18323606579371 +2.6872705756898227 -2.113963168457147
# alpha   0.12352950155931144 +0.05128752288660107 -0.03764114748246701

# %%
sresults.summary()
# Out:
# Summary
# =======
# nlive: 300
# niter: 4730
# ncall: 112906
# eff(%):  4.455
# logz: -63.265 +/-  0.320

# %%
sresults.summary()
# Out:
# Summary
# =======
# nlive: 300
# niter: 4613
# ncall: 114606
# eff(%):  4.287
# logz: -62.858 +/-  0.315

# %% [markdown]
# Ok now let's move on with the Gaussian profile:

# %%
sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'gprofile'],ptform_args=['gprofile'],nlive=300)
sampler.run_nested()
sresults2 = sampler.results
# Out:
# 5145it [02:03, 41.74it/s, +300 | bound: 151 | nc: 1 | ncall: 79638 | eff(%):  6.863 | loglstar:   -inf < -52.417 <    inf | logz: -68.316 +/-  0.223 | dlogz:  0.001 >  0.309]

# %%
sampler = dynesty.NestedSampler(loglike, ptform, ndim,logl_args=[data,'gprofile'],ptform_args=['gprofile'],nlive=300)
sampler.run_nested()
sresults2 = sampler.results
# Out:
# 2413it [00:34,  5.74it/s, bound: 89 | nc: 286 | ncall: 43674 | eff(%):  5.525 | loglstar:   -inf < -86.770 <    inf | logz: -94.415 +/-  0.149 | dlogz: 32.371 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2415it [00:36,  3.62it/s, bound: 91 | nc: 1608 | ncall: 45441 | eff(%):  5.315 | loglstar:   -inf < -86.731 <    inf | logz: -94.411 +/-  0.149 | dlogz: 32.359 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2418it [00:36,  4.07it/s, bound: 92 | nc: 565 | ncall: 46118 | eff(%):  5.243 | loglstar:   -inf < -86.694 <    inf | logz: -94.404 +/-  0.149 | dlogz: 32.342 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2419it [00:37,  3.19it/s, bound: 93 | nc: 1009 | ncall: 47127 | eff(%):  5.133 | loglstar:   -inf < -86.685 <    inf | logz: -94.401 +/-  0.149 | dlogz: 32.337 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2420it [00:39,  1.73it/s, bound: 94 | nc: 2769 | ncall: 49896 | eff(%):  4.850 | loglstar:   -inf < -86.682 <    inf | logz: -94.399 +/-  0.149 | dlogz: 32.331 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2421it [00:41,  1.18it/s, bound: 95 | nc: 2672 | ncall: 52568 | eff(%):  4.605 | loglstar:   -inf < -86.659 <    inf | logz: -94.397 +/-  0.149 | dlogz: 32.325 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2422it [00:42,  1.09it/s, bound: 96 | nc: 1475 | ncall: 54043 | eff(%):  4.482 | loglstar:   -inf < -86.627 <    inf | logz: -94.394 +/-  0.149 | dlogz: 32.320 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2423it [00:44,  1.01s/it, bound: 97 | nc: 1747 | ncall: 55790 | eff(%):  4.343 | loglstar:   -inf < -86.611 <    inf | logz: -94.392 +/-  0.149 | dlogz: 32.314 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2432it [00:46,  4.35it/s, bound: 100 | nc: 40 | ncall: 58626 | eff(%):  4.148 | loglstar:   -inf < -86.457 <    inf | logz: -94.368 +/-  0.150 | dlogz: 32.260 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2630it [00:52, 50.97it/s, bound: 118 | nc: 32 | ncall: 65496 | eff(%):  4.016 | loglstar:   -inf < -82.171 <    inf | logz: -92.520 +/-  0.169 | dlogz: 29.767 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2642it [00:53, 16.33it/s, bound: 121 | nc: 148 | ncall: 67515 | eff(%):  3.913 | loglstar:   -inf < -81.763 <    inf | logz: -92.304 +/-  0.171 | dlogz: 29.514 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2650it [00:54, 13.96it/s, bound: 123 | nc: 66 | ncall: 68557 | eff(%):  3.865 | loglstar:   -inf < -81.595 <    inf | logz: -92.151 +/-  0.172 | dlogz: 29.335 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2655it [00:54, 16.87it/s, bound: 124 | nc: 32 | ncall: 68713 | eff(%):  3.864 | loglstar:   -inf < -81.517 <    inf | logz: -92.059 +/-  0.173 | dlogz: 29.225 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2665it [00:56,  9.38it/s, bound: 127 | nc: 171 | ncall: 71042 | eff(%):  3.751 | loglstar:   -inf < -81.348 <    inf | logz: -91.875 +/-  0.174 | dlogz: 29.007 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2679it [00:58,  9.25it/s, bound: 131 | nc: 176 | ncall: 73331 | eff(%):  3.653 | loglstar:   -inf < -81.053 <    inf | logz: -91.630 +/-  0.175 | dlogz: 28.715 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2683it [01:02,  2.57it/s, bound: 133 | nc: 183 | ncall: 78310 | eff(%):  3.426 | loglstar:   -inf < -80.976 <    inf | logz: -91.560 +/-  0.175 | dlogz: 28.632 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2685it [01:03,  2.35it/s, bound: 134 | nc: 228 | ncall: 79856 | eff(%):  3.362 | loglstar:   -inf < -80.900 <    inf | logz: -91.525 +/-  0.175 | dlogz: 28.591 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2686it [01:03,  2.58it/s, bound: 135 | nc: 269 | ncall: 80125 | eff(%):  3.352 | loglstar:   -inf < -80.900 <    inf | logz: -91.507 +/-  0.175 | dlogz: 28.569 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2687it [01:03,  2.67it/s, bound: 136 | nc: 404 | ncall: 80529 | eff(%):  3.337 | loglstar:   -inf < -80.832 <    inf | logz: -91.489 +/-  0.175 | dlogz: 28.548 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2688it [01:04,  2.19it/s, bound: 137 | nc: 920 | ncall: 81449 | eff(%):  3.300 | loglstar:   -inf < -80.800 <    inf | logz: -91.470 +/-  0.175 | dlogz: 28.527 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2695it [01:06,  4.63it/s, bound: 139 | nc: 53 | ncall: 84578 | eff(%):  3.186 | loglstar:   -inf < -80.628 <    inf | logz: -91.334 +/-  0.176 | dlogz: 28.368 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2706it [01:08,  7.35it/s, bound: 141 | nc: 113 | ncall: 86557 | eff(%):  3.126 | loglstar:   -inf < -80.304 <    inf | logz: -91.120 +/-  0.177 | dlogz: 28.118 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2709it [01:09,  5.12it/s, bound: 144 | nc: 843 | ncall: 87770 | eff(%):  3.086 | loglstar:   -inf < -80.245 <    inf | logz: -91.059 +/-  0.177 | dlogz: 28.047 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2711it [01:12,  2.28it/s, bound: 146 | nc: 552 | ncall: 91136 | eff(%):  2.975 | loglstar:   -inf < -80.199 <    inf | logz: -91.019 +/-  0.177 | dlogz: 28.000 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2713it [01:16,  1.22it/s, bound: 148 | nc: 4501 | ncall: 96667 | eff(%):  2.807 | loglstar:   -inf < -80.138 <    inf | logz: -90.978 +/-  0.177 | dlogz: 27.953 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2714it [01:17,  1.16it/s, bound: 149 | nc: 1429 | ncall: 98096 | eff(%):  2.767 | loglstar:   -inf < -80.070 <    inf | logz: -90.957 +/-  0.177 | dlogz: 27.929 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2715it [01:17,  1.30it/s, bound: 150 | nc: 403 | ncall: 98499 | eff(%):  2.756 | loglstar:   -inf < -80.068 <    inf | logz: -90.936 +/-  0.177 | dlogz: 27.905 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2716it [01:19,  1.04s/it, bound: 151 | nc: 2988 | ncall: 101487 | eff(%):  2.676 | loglstar:   -inf < -80.048 <    inf | logz: -90.915 +/-  0.177 | dlogz: 27.881 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2717it [01:19,  1.13it/s, bound: 152 | nc: 441 | ncall: 101928 | eff(%):  2.666 | loglstar:   -inf < -80.006 <    inf | logz: -90.894 +/-  0.178 | dlogz: 27.857 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2718it [01:22,  1.33s/it, bound: 153 | nc: 3698 | ncall: 105626 | eff(%):  2.573 | loglstar:   -inf < -79.977 <    inf | logz: -90.873 +/-  0.178 | dlogz: 27.832 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2719it [01:29,  2.71s/it, bound: 154 | nc: 9440 | ncall: 115066 | eff(%):  2.363 | loglstar:   -inf < -79.948 <    inf | logz: -90.852 +/-  0.178 | dlogz: 27.808 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2720it [01:34,  3.23s/it, bound: 155 | nc: 6517 | ncall: 121583 | eff(%):  2.237 | loglstar:   -inf < -79.943 <    inf | logz: -90.831 +/-  0.178 | dlogz: 27.783 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2721it [01:35,  2.64s/it, bound: 156 | nc: 1491 | ncall: 123074 | eff(%):  2.211 | loglstar:   -inf < -79.890 <    inf | logz: -90.810 +/-  0.178 | dlogz: 27.759 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2722it [01:38,  2.80s/it, bound: 157 | nc: 4419 | ncall: 127493 | eff(%):  2.135 | loglstar:   -inf < -79.855 <    inf | logz: -90.788 +/-  0.178 | dlogz: 27.734 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2724it [01:39,  1.62s/it, bound: 158 | nc: 169 | ncall: 128698 | eff(%):  2.117 | loglstar:   -inf < -79.779 <    inf | logz: -90.744 +/-  0.178 | dlogz: 27.684 >  0.309] /Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2725it [01:39,  1.21s/it, bound: 159 | nc: 255 | ncall: 128953 | eff(%):  2.113 | loglstar:   -inf < -79.774 <    inf | logz: -90.722 +/-  0.178 | dlogz: 27.659 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2726it [01:40,  1.07s/it, bound: 160 | nc: 839 | ncall: 129792 | eff(%):  2.100 | loglstar:   -inf < -79.773 <    inf | logz: -90.701 +/-  0.178 | dlogz: 27.634 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2727it [01:40,  1.14it/s, bound: 161 | nc: 548 | ncall: 130340 | eff(%):  2.092 | loglstar:   -inf < -79.770 <    inf | logz: -90.680 +/-  0.178 | dlogz: 27.609 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2728it [01:41,  1.25it/s, bound: 162 | nc: 803 | ncall: 131143 | eff(%):  2.080 | loglstar:   -inf < -79.748 <    inf | logz: -90.659 +/-  0.178 | dlogz: 27.584 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2729it [01:43,  1.11s/it, bound: 163 | nc: 2550 | ncall: 133693 | eff(%):  2.041 | loglstar:   -inf < -79.651 <    inf | logz: -90.637 +/-  0.178 | dlogz: 27.560 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2819it [01:47, 52.03it/s, bound: 170 | nc: 12 | ncall: 138770 | eff(%):  2.031 | loglstar:   -inf < -77.508 <    inf | logz: -88.728 +/-  0.183 | dlogz: 25.351 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2895it [01:50, 24.88it/s, bound: 181 | nc: 108 | ncall: 142833 | eff(%):  2.027 | loglstar:   -inf < -75.457 <    inf | logz: -86.937 +/-  0.186 | dlogz: 23.307 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2899it [01:54,  4.26it/s, bound: 184 | nc: 2915 | ncall: 148839 | eff(%):  1.948 | loglstar:   -inf < -75.308 <    inf | logz: -86.851 +/-  0.186 | dlogz: 23.209 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 2909it [01:57,  5.10it/s, bound: 187 | nc: 109 | ncall: 152227 | eff(%):  1.911 | loglstar:   -inf < -75.107 <    inf | logz: -86.628 +/-  0.187 | dlogz: 22.952 >  0.309]/Users/dgerosa/box/lib/python3.11/site-packages/dynesty/bounding.py:707: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4956it [02:04, 39.77it/s, +300 | bound: 210 | nc: 1 | ncall: 161560 | eff(%):  3.259 | loglstar:   -inf < -52.423 <    inf | logz: -67.691 +/-  0.219 | dlogz:  0.001 >  0.309]

# %%
tfig, taxes = dyplot.traceplot(sresults2)

# %%
tfig, taxes = dyplot.traceplot(sresults2)

# %%
samples = sresults2.samples  # samples
weights = np.exp(sresults2.logwt - sresults2.logz[-1])  # normalized weights

labels = ["A","b","t0","sigmaW"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
samples = sresults2.samples  # samples
weights = np.exp(sresults2.logwt - sresults2.logz[-1])  # normalized weights

labels = ["A","b","t0","sigmaW"]

samples_equal = dyfunc.resample_equal(samples, weights)
corner.corner(samples_equal,labels=labels);

# %%
sresults2.summary()
# Out:
# Summary
# =======
# nlive: 300
# niter: 5145
# ncall: 79338
# eff(%):  6.863
# logz: -68.316 +/-  0.330

# %%
sresults2.summary()
# Out:
# Summary
# =======
# nlive: 300
# niter: 4956
# ncall: 161260
# eff(%):  3.259
# logz: -67.691 +/-  0.323

# %% [markdown]
# Now compute the odds ratio (assuming equal hyperpriors) between the two models:

# %%
np.exp(sresults.logz[-1])/np.exp(sresults2.logz[-1])
# Out:
# 156.22414490000781

# %%
np.exp(sresults.logz[-1])/np.exp(sresults2.logz[-1])
# Out:
# np.float64(125.61145662959846)

# %% [markdown]
# This is "very strong" evidence in favour of the burst model

# %% [markdown]
# Something I haven't done:
# - check if this number is robust with respect to the nested sampling hyperparameters (number of live points, dlogz threshold where the fit is terminated)
# - Assign an error to this estimate of the Bayes factor.

# %% [markdown]
# Let's plot some models

# %%
tgrid=np.linspace(0,100,100)

chosen_samples= samples_equal[np.random.choice(len(samples_equal),size=30)]

for chosen_theta in chosen_samples:

    ygrid =  burst(chosen_theta,tgrid)
    plt.plot(tgrid,ygrid,alpha=0.3,c='gray')
    
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux")
# Out:
# Text(0, 0.5, 'flux')

# %%
tgrid=np.linspace(0,100,100)

chosen_samples= samples_equal[np.random.choice(len(samples_equal),size=30)]

for chosen_theta in chosen_samples:

    ygrid =  burst(chosen_theta,tgrid)
    plt.plot(tgrid,ygrid,alpha=0.3,c='gray')
    
plt.errorbar(t,y,yerr=yerr,fmt='o')
plt.xlabel("time")
plt.ylabel("flux")
# Out:
# Text(0, 0.5, 'flux')

# %% [markdown]
# Indeed, look how badly this is describing the data...
#
# Remember this does not tell you that a model is correct, only that one is better than the other.

# %%
### Some tests I've done


### Here I played a bit with the fit by hand...
# tgrid=np.linspace(0,100,100)
# t0_quick=50
# A_quick=5
# b_quick=10
# sigmaW_quick=2
# theta_quick= np.array([A_quick,b_quick,t0_quick,sigmaW_quick])
# ygrid =  gprofile(theta_quick,tgrid)
# plt.errorbar(t,y,yerr=yerr,fmt='o')
# plt.xlabel("time")
# plt.ylabel("flux")
# plt.plot(tgrid,ygrid)

# %%
### Some tests I've done


### Here I played a bit with the fit by hand...
# tgrid=np.linspace(0,100,100)
# t0_quick=50
# A_quick=5
# b_quick=10
# sigmaW_quick=2
# theta_quick= np.array([A_quick,b_quick,t0_quick,sigmaW_quick])
# ygrid =  gprofile(theta_quick,tgrid)
# plt.errorbar(t,y,yerr=yerr,fmt='o')
# plt.xlabel("time")
# plt.ylabel("flux")
# plt.plot(tgrid,ygrid)

# %%
### Some tests I've done

### Here I convinced myself I understand what ppf is doing

# def ptform(u,model):
#     """Transforms the uniform random variables `u ~ Unif[0., 1.)`
#     to the parameters of interest."""
# 
#     x = np.array(u)  # copy u
# 
#     x[0] = scipy.stats.uniform(loc=Amin,scale=Amax-Amin).ppf(u[0])
#     x[1] = scipy.stats.uniform(loc=bmin,scale=bmax-bmin).ppf(u[1])
#     x[2] = scipy.stats.uniform(loc=t0min,scale=t0max-t0min).ppf(u[2])
# 
#     if model =='burst':
#         x[3] = scipy.stats.loguniform.ppf(u[3],alphamin,alphamax)
#     elif model =='gprofile':
#         x[3] = scipy.stats.loguniform.ppf(u[3],sigmaWmin,sigmaWmax)
#         #x[3] = scipy.stats.uniform(loc=sigmaWmin,scale=sigmaWmax-sigmaWmin).ppf(u[3])
# 
#     return x

# myu= np.random.uniform(0,1,4000).reshape(4,1000)
# myp = ptform(myu, 'burst')
# plt.hist(np.log(myp[3]))
# y=scipy.stats.loguniform.ppf(np.random.uniform(0,1,1000),sigmaWmin,sigmaWmax)
# plt.hist(np.log(y))

# %%
### Some tests I've done

### Here I convinced myself I understand what ppf is doing

# def ptform(u,model):
#     """Transforms the uniform random variables `u ~ Unif[0., 1.)`
#     to the parameters of interest."""
# 
#     x = np.array(u)  # copy u
# 
#     x[0] = scipy.stats.uniform(loc=Amin,scale=Amax-Amin).ppf(u[0])
#     x[1] = scipy.stats.uniform(loc=bmin,scale=bmax-bmin).ppf(u[1])
#     x[2] = scipy.stats.uniform(loc=t0min,scale=t0max-t0min).ppf(u[2])
# 
#     if model =='burst':
#         x[3] = scipy.stats.loguniform.ppf(u[3],alphamin,alphamax)
#     elif model =='gprofile':
#         x[3] = scipy.stats.loguniform.ppf(u[3],sigmaWmin,sigmaWmax)
#         #x[3] = scipy.stats.uniform(loc=sigmaWmin,scale=sigmaWmax-sigmaWmin).ppf(u[3])
# 
#     return x

# myu= np.random.uniform(0,1,4000).reshape(4,1000)
# myp = ptform(myu, 'burst')
# plt.hist(np.log(myp[3]))
# y=scipy.stats.loguniform.ppf(np.random.uniform(0,1,1000),sigmaWmin,sigmaWmax)
# plt.hist(np.log(y))
